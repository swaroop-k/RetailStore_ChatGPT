# %%
# importing the libraries

import pandas as pd

# %%
# loading the dataset

retail_data = pd.read_csv(r'.\data\realistic_retail_data.csv')
retail_data.head()
# Out:
#    CustomerID  Age  Gender    City  TransactionID      TransactionDate  \
# 0        1000   56   Other  City C          10000  2022-01-01 00:00:00
# 1        1001   69  Female  City C          10001  2022-01-01 01:00:00
# 2        1002   46  Female  City C          10002  2022-01-01 02:00:00
# 3        1003   32    Male  City C          10003  2022-01-01 03:00:00
# 4        1004   60  Female  City B          10004  2022-01-01 04:00:00
#
#    AmountSpent  ProductID ProductCategory  ProductRating PaymentMethod  \
# 0       259.52        308            Home            1.2    Debit Card
# 1       206.11        496            Toys            3.0        PayPal
# 2        27.18        489            Toys            1.1        PayPal
# 3       478.96        293          Beauty            1.7    Debit Card
# 4       476.67        363            Home            2.5   Credit Card
#
#    IsReturned DeliveryStatus  DeliveryTimeDays  DeliveryFee FeedbackScore  \
# ...

# %%
# datatypes of the columns in the data frame
retail_data.dtypes
# Out:
# CustomerID                int64
# Age                       int64
# Gender                   object
# City                     object
# TransactionID             int64
# TransactionDate          object
# AmountSpent             float64
# ProductID                 int64
# ProductCategory          object
# ProductRating           float64
# PaymentMethod            object
# IsReturned                int64
# DeliveryStatus           object
# DeliveryTimeDays          int64
# DeliveryFee             float64
# FeedbackScore            object
# ReviewLength              int64
# CustomerSatisfaction     object
# dtype: object

# %%
# null data is present or not
retail_data.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# City                    0
# TransactionID           0
# TransactionDate         0
# AmountSpent             0
# ProductID               0
# ProductCategory         0
# ProductRating           0
# PaymentMethod           0
# IsReturned              0
# DeliveryStatus          0
# DeliveryTimeDays        0
# DeliveryFee             0
# FeedbackScore           0
# ReviewLength            0
# CustomerSatisfaction    0
# dtype: int64

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            10000 non-null  int64
#  1   Age                   10000 non-null  int64
#  2   Gender                10000 non-null  object
#  3   City                  10000 non-null  object
#  4   TransactionID         10000 non-null  int64
#  5   TransactionDate       10000 non-null  object
#  6   AmountSpent           10000 non-null  float64
#  7   ProductID             10000 non-null  int64
#  8   ProductCategory       10000 non-null  object
#  9   ProductRating         10000 non-null  float64
#  10  PaymentMethod         10000 non-null  object
#  11  IsReturned            10000 non-null  int64
#  12  DeliveryStatus        10000 non-null  object
#  13  DeliveryTimeDays      10000 non-null  int64
#  14  DeliveryFee           10000 non-null  float64
# ...

# %%
# derive statistics 
# it will return only numeric columns
retail_data.describe(include='all')
# Out:
#          CustomerID           Age Gender    City  TransactionID  \
# count   10000.00000  10000.000000  10000   10000    10000.00000
# unique          NaN           NaN      3       4            NaN
# top             NaN           NaN   Male  City B            NaN
# freq            NaN           NaN   3375    2586            NaN
# mean     5999.50000     43.539400    NaN     NaN    14999.50000
# std      2886.89568     14.911636    NaN     NaN     2886.89568
# min      1000.00000     18.000000    NaN     NaN    10000.00000
# 25%      3499.75000     31.000000    NaN     NaN    12499.75000
# 50%      5999.50000     43.000000    NaN     NaN    14999.50000
# 75%      8499.25000     56.000000    NaN     NaN    17499.25000
# max     10999.00000     69.000000    NaN     NaN    19999.00000
#
#             TransactionDate   AmountSpent     ProductID ProductCategory  \
# count                 10000  10000.000000  10000.000000           10000
# ...

# %%
# Changes needs to be done
'''
    1. convert the transactiondate to datetimeformat
'''

# the format was already good like %yyyy-%mm-%dd hh:mm:ss
retail_data['TransactionDate'] = pd.to_datetime(retail_data['TransactionDate'])  
retail_data.dtypes
# Out:
# CustomerID                       int64
# Age                              int64
# Gender                          object
# City                            object
# TransactionID                    int64
# TransactionDate         datetime64[ns]
# AmountSpent                    float64
# ProductID                        int64
# ProductCategory                 object
# ProductRating                  float64
# PaymentMethod                   object
# IsReturned                       int64
# DeliveryStatus                  object
# DeliveryTimeDays                 int64
# DeliveryFee                    float64
# FeedbackScore                   object
# ReviewLength                     int64
# CustomerSatisfaction            object
# dtype: object
